# %% [markdown]
# # imports

# %%
import datetime
import pandas as pd, numpy as np
import scipy
import matplotlib.pyplot as plt
from numpy_ext import rolling_apply as rolling_apply_ext
import talib
from talib import MA_Type

# %%
df = pd.read_csv('market_data_binance.by_minute_ALL_2022-09-19T04:00:00Z_2022-09-26T03:59:00Z.csv')
df['time'] = pd.to_datetime(df['timestamp'], unit='s')
df_close = df.pivot(index='time', columns='symbol', values='close')

# %%
def get_close_between_datetime(sample_period_minutes, symbols, start_datetime_str, end_datetime_str):   
    return df_close[(df_close.index >= start_datetime_str) & (df_close.index < end_datetime_str)][symbols].resample(f'{sample_period_minutes}min').last()

def get_close_between_date(sample_period_minutes, symbols, start_date_str, end_date_str):   
    return get_close_between_datetime(sample_period_minutes, symbols, start_date_str + " 00:00:000", end_date_str + " 00:00:000")

# %%
date_str_20220919 = "2022-09-19"
date_str_20220920 = "2022-09-20"
date_str_20220921 = "2022-09-21"
date_str_20220922 = "2022-09-22"
date_str_20220923 = "2022-09-23"
date_str_20220924 = "2022-09-24"
date_str_20220925 = "2022-09-25"
#symbols = ['YFIIUSDT', 'ETHUSDT', 'PAXGUSDT', 'BIFIUSDT', 'BNBUSDT']
symbols = ['YFIIUSDT', 'ETHUSDT', 'BIFIUSDT']

# %%
get_close_between_date(10, symbols, date_str_20220920, date_str_20220921)
# Out:
# symbol               YFIIUSDT  ETHUSDT  BIFIUSDT
# time
# 2022-09-20 00:00:00     893.5  1383.20     349.6
# 2022-09-20 00:10:00     886.7  1367.95     350.1
# 2022-09-20 00:20:00     886.3  1368.34     349.8
# 2022-09-20 00:30:00     884.1  1368.65     349.8
# 2022-09-20 00:40:00     880.3  1365.77     349.8
# ...                       ...      ...       ...
# 2022-09-20 23:10:00     863.7  1321.81     345.8
# 2022-09-20 23:20:00     866.6  1323.96     346.2
# 2022-09-20 23:30:00     863.3  1323.64     346.2
# 2022-09-20 23:40:00     864.1  1323.84     345.5
# 2022-09-20 23:50:00     866.3  1322.93     343.9
#
# [144 rows x 3 columns]

# %%
df = get_close_between_date(5, symbols, "2022-09-20", "2022-09-21")
(df / df.iloc[0]).plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Sanity check: eigen values, vectors

# %%
mat = [[1, 2, 0], [2, 1, 0], [0, 0, 4]]
eiven_vals, eigen_vecs = np.linalg.eig(mat)

# %%
eiven_vals
# Out:
# array([ 3., -1.,  4.])

# %%
eigen_vecs
# Out:
# array([[ 0.70710678, -0.70710678,  0.        ],
#        [ 0.70710678,  0.70710678,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])

# %% [markdown]
# The normalized (unit “length”) eigenvectors, such that the column v[:,i] is the eigenvector corresponding to the eigenvalue w[i].

# %%
eigen_vecs[:,0]
# Out:
# array([0.70710678, 0.70710678, 0.        ])

# %% [markdown]
# note that the matrix represenation is bit confusing. v[i,:] is *not* eigenvector, but v[:,i] is. So below is *not* an eigen vector.

# %%
eigen_vecs[0]
# Out:
# array([ 0.70710678, -0.70710678,  0.        ])

# %% [markdown]
# and accordingly the eigenvalues matix on the rhs is to be horizontally layed down.

# %%
eigen_vecs @ np.diag(eiven_vals) @ eigen_vecs.T
# Out:
# array([[1., 2., 0.],
#        [2., 1., 0.],
#        [0., 0., 4.]])

# %%
mat @ eigen_vecs[:,0]
# Out:
# array([2.12132034, 2.12132034, 0.        ])

# %% [markdown]
# # Solve the minimal predictability condition

# %%
get_close_between_date(10, symbols, "2022-09-19", "2022-09-21").plot()
# Out:
# <Axes: xlabel='time'>

# %%
get_close_between_date(10, symbols, "2022-09-19", "2022-09-21").corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c1195_row0_col0, #T_c1195_row1_col1, #T_c1195_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c1195_row0_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c1195_row0_col2, #T_c1195_row2_col0, #T_c1195_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c1195_row1_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_c1195_row1_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# </style>
# <table id="T_c1195">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_c1195_level0_col0" class="col_heading level0 col0" >YFIIUSDT</th>
#       <th id="T_c1195_level0_col1" class="col_heading level0 col1" >ETHUSDT</th>
#       <th id="T_c1195_level0_col2" class="col_heading level0 col2" >BIFIUSDT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1195_level0_row0" class="row_heading level0 row0" >YFIIUSDT</th>
#       <td id="T_c1195_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c1195_row0_col1" class="data row0 col1" >0.930983</td>
#       <td id="T_c1195_row0_col2" class="data row0 col2" >0.824657</td>
#     </tr>
#     <tr>
#       <th id="T_c1195_level0_row1" class="row_heading level0 row1" >ETHUSDT</th>
#       <td id="T_c1195_row1_col0" class="data row1 col0" >0.930983</td>
#       <td id="T_c1195_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c1195_row1_col2" class="data row1 col2" >0.867188</td>
#     </tr>
#     <tr>
#       <th id="T_c1195_level0_row2" class="row_heading level0 row2" >BIFIUSDT</th>
#       <td id="T_c1195_row2_col0" class="data row2 col0" >0.824657</td>
#       <td id="T_c1195_row2_col1" class="data row2 col1" >0.867188</td>
#       <td id="T_c1195_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_close_between_date(1, symbols, "2022-09-19", "2022-09-21").corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_14068_row0_col0, #T_14068_row1_col1, #T_14068_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_14068_row0_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_14068_row0_col2, #T_14068_row2_col0, #T_14068_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_14068_row1_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_14068_row1_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# </style>
# <table id="T_14068">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_14068_level0_col0" class="col_heading level0 col0" >YFIIUSDT</th>
#       <th id="T_14068_level0_col1" class="col_heading level0 col1" >ETHUSDT</th>
#       <th id="T_14068_level0_col2" class="col_heading level0 col2" >BIFIUSDT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14068_level0_row0" class="row_heading level0 row0" >YFIIUSDT</th>
#       <td id="T_14068_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_14068_row0_col1" class="data row0 col1" >0.925849</td>
#       <td id="T_14068_row0_col2" class="data row0 col2" >0.821544</td>
#     </tr>
#     <tr>
#       <th id="T_14068_level0_row1" class="row_heading level0 row1" >ETHUSDT</th>
#       <td id="T_14068_row1_col0" class="data row1 col0" >0.925849</td>
#       <td id="T_14068_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_14068_row1_col2" class="data row1 col2" >0.865456</td>
#     </tr>
#     <tr>
#       <th id="T_14068_level0_row2" class="row_heading level0 row2" >BIFIUSDT</th>
#       <td id="T_14068_row2_col0" class="data row2 col0" >0.821544</td>
#       <td id="T_14068_row2_col1" class="data row2 col1" >0.865456</td>
#       <td id="T_14068_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_close_between_date(10, symbols, "2022-09-19", "2022-09-24").corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3cec3_row0_col0, #T_3cec3_row1_col1, #T_3cec3_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3cec3_row0_col1, #T_3cec3_row0_col2, #T_3cec3_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3cec3_row1_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_3cec3_row2_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_3cec3_row2_col1 {
#   background-color: #f6a283;
#   color: #000000;
# }
# </style>
# <table id="T_3cec3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_3cec3_level0_col0" class="col_heading level0 col0" >YFIIUSDT</th>
#       <th id="T_3cec3_level0_col1" class="col_heading level0 col1" >ETHUSDT</th>
#       <th id="T_3cec3_level0_col2" class="col_heading level0 col2" >BIFIUSDT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cec3_level0_row0" class="row_heading level0 row0" >YFIIUSDT</th>
#       <td id="T_3cec3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3cec3_row0_col1" class="data row0 col1" >0.064190</td>
#       <td id="T_3cec3_row0_col2" class="data row0 col2" >0.479641</td>
#     </tr>
#     <tr>
#       <th id="T_3cec3_level0_row1" class="row_heading level0 row1" >ETHUSDT</th>
#       <td id="T_3cec3_row1_col0" class="data row1 col0" >0.064190</td>
#       <td id="T_3cec3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3cec3_row1_col2" class="data row1 col2" >0.745906</td>
#     </tr>
#     <tr>
#       <th id="T_3cec3_level0_row2" class="row_heading level0 row2" >BIFIUSDT</th>
#       <td id="T_3cec3_row2_col0" class="data row2 col0" >0.479641</td>
#       <td id="T_3cec3_row2_col1" class="data row2 col1" >0.745906</td>
#       <td id="T_3cec3_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_close_between_date(1, symbols, "2022-09-19", "2022-09-24").corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_80e9b_row0_col0, #T_80e9b_row1_col1, #T_80e9b_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_80e9b_row0_col1, #T_80e9b_row0_col2, #T_80e9b_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_80e9b_row1_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_80e9b_row2_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_80e9b_row2_col1 {
#   background-color: #f6a283;
#   color: #000000;
# }
# </style>
# <table id="T_80e9b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_80e9b_level0_col0" class="col_heading level0 col0" >YFIIUSDT</th>
#       <th id="T_80e9b_level0_col1" class="col_heading level0 col1" >ETHUSDT</th>
#       <th id="T_80e9b_level0_col2" class="col_heading level0 col2" >BIFIUSDT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80e9b_level0_row0" class="row_heading level0 row0" >YFIIUSDT</th>
#       <td id="T_80e9b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_80e9b_row0_col1" class="data row0 col1" >0.068271</td>
#       <td id="T_80e9b_row0_col2" class="data row0 col2" >0.480184</td>
#     </tr>
#     <tr>
#       <th id="T_80e9b_level0_row1" class="row_heading level0 row1" >ETHUSDT</th>
#       <td id="T_80e9b_row1_col0" class="data row1 col0" >0.068271</td>
#       <td id="T_80e9b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_80e9b_row1_col2" class="data row1 col2" >0.745821</td>
#     </tr>
#     <tr>
#       <th id="T_80e9b_level0_row2" class="row_heading level0 row2" >BIFIUSDT</th>
#       <td id="T_80e9b_row2_col0" class="data row2 col0" >0.480184</td>
#       <td id="T_80e9b_row2_col1" class="data row2 col1" >0.745821</td>
#       <td id="T_80e9b_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# the eigen_vecs are for calculation only, the actual distribution over the asset is returned in `wgts`.

# %%
def calc_autocov_matrix(arr, lag):
    m = arr.shape[0]  # sample size.
    arr_lead = arr[lag:]
    arr_lag = arr[:m-lag]
    return 1.0 / (m - lag - 1) * (arr_lead - np.nanmean(arr_lead, axis=0)).T @ (arr_lag - np.nanmean(arr_lag, axis=0))

# %%
def get_var1_wgts_values_transpose(*df_values_T):
    cov = np.cov(df_values_T)
    cov_inv = np.linalg.inv(cov)
    cov_inv_sqrt = scipy.linalg.sqrtm(cov_inv)
    autocov = calc_autocov_matrix(np.transpose(df_values_T), 1)
    #var_predictability = cov_inv_sqrt @ autocov @ cov @ autocov.T @ cov_inv_sqrt.T
    var_predictability = cov_inv_sqrt @ autocov @ cov_inv @ autocov.T @ cov_inv_sqrt.T

    var_eigen_vals, var_eigen_vecs = np.linalg.eig(var_predictability)

    asc = np.argsort(var_eigen_vals)
    var_eigen_vals, var_eigen_vecs = var_eigen_vals[asc], var_eigen_vecs[:, asc]
    wgts = cov_inv_sqrt @ var_eigen_vecs
    if np.sign((np.transpose(df_values_T) @ wgts[:,0])[-1]) < 0:
        pass # var_eigen_vecs, wgts = var_eigen_vecs * -1, wgts * -1
    if np.sign(wgts[-1,0]) < 0:
        var_eigen_vecs, wgts = var_eigen_vecs * -1, wgts * -1
    return var_eigen_vals, var_eigen_vecs, wgts

# %%
def get_var1_wgts(df):
    return get_var1_wgts_values_transpose(*df.values.T)

# %% [markdown]
# The same function that takes df.values.T instead of df itself. This is used in the custom rolling function as the custom rolling function does not take the data frame but the arrays.

# %% [markdown]
# # Trading calculations

# %%
def bband(values, window, stds):
    df_band = values.copy()
    df_band['upper'] = (values.ewm(alpha=0.1).mean() + stds * values.rolling(window).std()) # * values.rolling(window).apply(adjustment_factor))
    df_band['lower'] = (values.ewm(alpha=0.1).mean() - stds * values.rolling(window).std()) # / values.rolling(window).apply(adjustment_factor))
    return df_band

# %%
class TradingParam:
    def __init__(self, bb_windows, bb_stdev):
        self.bb_windows, self.bb_stdev = bb_windows, bb_stdev

def add_features(df_prices, wgt, trading_param):
    df_prices_weighted = df_prices * wgt
    values = df_prices_weighted.sum(axis=1).to_frame().rename(columns={0: 'value'})

    # rebalance
    if type(wgt) is np.ndarray:
        values['rebalanced'] = 0
    else:
        values['rebalanced'] = wgt.sum(axis=1).to_frame().diff().fillna(0)
    values = values.fillna(0)
    values['rebalanced'] = values[['rebalanced']].where(values.rebalanced == 0, 1)

    rebalance_ages = [1]
    for i in range(1, len(values.index)):
        rebalance_age = rebalance_ages[-1] + 1
        if values.rebalanced.values[i] > 0:
            rebalance_age = 1
        rebalance_ages.append(rebalance_age)
    values['rebalance_age'] = rebalance_ages

    # bband and crossing
    '''
    upper, middle, lower = talib.BBANDS(values.value, trading_param.bb_windows, trading_param.bb_stdev, matype=MA_Type.T3)
    '''
    df_band = bband(values.value, trading_param.bb_windows, trading_param.bb_stdev)
    upper, lower = df_band.upper, df_band.lower

    values['upper'] = upper
    values['lower'] = lower 
    #upper, middle, lower, values = upper.dropna(), middle.dropna(), lower.dropna(), values.dropna()
    
    values['value_prev'] = values.value.shift()
    values['lower_crossed_upward'] = ((values.value_prev <= lower.shift()) & (values.value >= lower)).astype(np.int32)
    values['lower_crossed_downward'] = ((values.value_prev >= lower.shift()) & (values.value <= lower)).astype(np.int32)
    values['upper_crossed_upward'] = ((values.value_prev <= upper.shift()) & (values.value >= upper)).astype(np.int32)
    values['upper_crossed_downward'] = ((values.value_prev >= upper.shift()) & (values.value <= upper)).astype(np.int32)
    values = values.dropna()

    # in/out position with bband
    in_positions = [0]
    for i in range(1, len(values.index)):
        in_position = in_positions[-1]
        # if i_decision = i-1, the position of current is one step delayed to make it more realistic.
        # on the other hand, it might be too unrealistically strigent condition
        decision_delay = 0
        i_decision = i - decision_delay
        if values.lower_crossed_upward.values[i_decision] > 0: in_position = 1
        #elif values.upper_crossed_upward.values[i_decision] > 0: in_position = 1
        elif values.upper_crossed_downward.values[i_decision] > 0: in_position = 0
        #elif values.lower_crossed_downward.values[i_decision] > 0: in_position = 0
        in_positions.append(in_position)
    values['in_position'] = in_positions
    values['position_changed'] = values.in_position.diff()

    # tba
    values_in_position = [values.value.iloc[i] for i in range(len(values.index))]
    wgt_position_entered = None
    for i, index in enumerate(values.index):
        if type(wgt) is np.ndarray:
            wgt_position_entered = wgt
        else:
            if wgt_position_entered is None or values.position_changed.loc[index] == 1 or values.in_position.shift().loc[index] == 0:
                wgt_position_entered = wgt.loc[index]
        values_in_position[i] = (df_prices.loc[index] * wgt_position_entered).sum()
    values['value_in_position'] = values_in_position

    # position size
    df_prices_weighted['pos_mean_size'] = df_prices_weighted.where(df_prices_weighted > 0).mean(1)
    df_prices_weighted['neg_mean_size'] = -df_prices_weighted.where(df_prices_weighted <= 0).mean(1)
    df_prices_weighted['mean_size'] = df_prices_weighted[['pos_mean_size', 'neg_mean_size']].mean(1)
    values['mean_size'] = df_prices_weighted['mean_size']

    position_sizes = [0]
    for i in range(1, len(values.index)):
        position_size = position_sizes[-1]
        # the position of current is one step delayed to make it more realistic.
        if values.position_changed.values[i-1] > 0:
            position_size = values.mean_size.values[i]
        if values.position_changed.values[i-1] < 0:
            position_size = 0
        position_sizes.append(position_size)
    values['position_size'] = position_sizes

    # pnl
    # the result of position of current cycle gets reflected in the next cycle to prevent look-ahead bias.
    values['profit_raw'] = values.value_in_position.diff() * values.in_position.shift()
    values['profit'] = values.value_in_position.pct_change() * values.in_position.shift()

    return values

# %% [markdown]
# # Static Portfolio construction

# %%
#df_prices = get_close_between_date(10, symbols, date_str_20220919, date_str_20220922)
df_prices = get_close_between_date(1, symbols, date_str_20220919, date_str_20220922)
var_eigen_vals, var_eigen_vecs, wgts = get_var1_wgts_values_transpose(*df_prices.values.T)

# %%
var_eigen_vals
# Out:
# array([0.94074868, 0.97783309, 0.99276419])

# %%
print(var_eigen_vecs[:,0])
print(wgts[:,0])
# Out:
# [-0.38076875 -0.08217091  0.921012  ]
# [-0.06350456 -0.02646201  0.38747263]

# %%
print(var_eigen_vecs[:,-1])
print(wgts[:,-1])
# Out:
# [0.44267965 0.85828222 0.25958881]
# [0.01346659 0.02183511 0.06154249]

# %%
get_close_between_date(10, symbols, date_str_20220919, date_str_20220921).head(3)
# Out:
# symbol               YFIIUSDT  ETHUSDT  BIFIUSDT
# time
# 2022-09-19 04:00:00     834.2  1300.92     340.1
# 2022-09-19 04:10:00     834.6  1303.61     340.1
# 2022-09-19 04:20:00     835.4  1303.85     343.0

# %% [markdown]
# ## Graphs

# %%
(get_close_between_date(10, symbols, date_str_20220919, date_str_20220921) * var_eigen_vecs[:,0]).sum(axis=1).plot()
# Out:
# <Axes: xlabel='time'>

# %%
(get_close_between_date(2, symbols, date_str_20220919, date_str_20220922) * wgts[:,0]).sum(axis=1).plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ## Bollinger bands trading

# %%
trading_param = TradingParam(60, 2.0)
values = add_features(df_prices, wgts[:,0], trading_param)

# %%
(values.profit_raw / values.position_size).cumsum().plot()
# Out:
# <Axes: xlabel='time'>

# %%
ax = values.profit_raw.cumsum().iloc[:,].plot(figsize=(9, 6))
ymin, ymax = 0, values.profit_raw.cumsum().max()

# add vertical lines
ax.vlines(x=list(values[values.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values[values.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %%
values[['value', 'upper', 'lower']].plot()
# Out:
# <Axes: xlabel='time'>

# %%
values[['value', 'upper', 'lower']].dropna().iloc[400:700,].plot(figsize=(9, 6))
# Out:
# <Axes: xlabel='time'>

# %%
ax = values[['value', 'upper', 'lower']].dropna().iloc[400:700,].plot(figsize=(9, 6))
ymin, ymax = values.iloc[400:700,].value.min(), values.iloc[400:700,].value.max()

# add vertical lines
ax.vlines(x=list(values[values.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values[values.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %%
# plot dataframe; the index is a datetime index
ax = values[['value', 'upper', 'lower']].dropna().plot(figsize=(9, 6))
ymin, ymax = values.value.min(), values.value.max()

# add vertical lines
ax.vlines(x=list(values_rolling[values_rolling.position_changed == -1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values_rolling[values_rolling.position_changed == +1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')
ax.vlines(x=list(values[values.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values[values.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %% [markdown]
# # Rolling-based Portfolio Construction

# %%
from numpy_ext import rolling_apply as rolling_apply_ext

# %%
def get_var1_wgts_values_transpose_rolling(df_prices, window, step, sample_unit_minutes, order, if_evecs):
    '''
    order: 0 for the smallest eigen value, -1 for the largest.
    if_evecs: True for eigen vectors, False for weights (e-vecs / sqrt(cov))
    '''
    i = 1 if if_evecs else 2
    rolling_wgt = rolling_apply_ext(lambda *vsT: get_var1_wgts_values_transpose(*vsT)[i][:,order], window, *df_prices.values.T)
    df_rolling_wgt = pd.DataFrame(rolling_wgt, index=df_prices.index, columns=df_prices.columns)
    # shift by one time unit as the weight up to now will practically be applied in the next step. (?)
    df_rolling_wgt = df_rolling_wgt.shift()
    df_rolling_wgt_resampled = df_rolling_wgt.resample(f'{step * sample_unit_minutes}min').first().resample(f'{sample_unit_minutes}min').first().ffill()
    return df_rolling_wgt_resampled

# %%
rebalance_period = 1
df_prices = get_close_between_date(1, symbols, date_str_20220919, date_str_20220922)
evecs_rolling = get_var1_wgts_values_transpose_rolling(
    df_prices, window=180, step=rebalance_period, sample_unit_minutes=1, order=0, if_evecs=True)
wgt_rolling = get_var1_wgts_values_transpose_rolling(
    df_prices, window=180, step=rebalance_period, sample_unit_minutes=1, order=0, if_evecs=False)

# %%
wgt_rolling.plot()
# Out:
# <Axes: xlabel='time'>

# %%
(df_prices * wgt_rolling).plot()
# Out:
# <Axes: xlabel='time'>

# %%
trading_param = TradingParam(60, 2.0)
values_rolling = add_features(df_prices, wgt_rolling, trading_param)

# %%
values_rolling[['value', 'upper', 'lower', 'value_in_position']].plot(figsize=(9, 6))
# Out:
# <Axes: xlabel='time'>

# %%
# plot dataframe; the index is a datetime index
ax = values_rolling[['value', 'upper', 'lower']].iloc[:400].plot(figsize=(9, 6))
#ax = values_rolling[['value']].plot(figsize=(9, 6))
ymin, ymax = values_rolling.value.min(), values_rolling.value.max()

ax.vlines(x=list(values_rolling[values_rolling.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values_rolling[values_rolling.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %%
# plot dataframe; the index is a datetime index
#ax = values_rolling[['value', 'upper', 'lower']].plot(figsize=(9, 6))
ax = values_rolling[['value', 'value_in_position']].plot(figsize=(9, 6))
ymin, ymax = values_rolling.value.min(), values_rolling.value.max()

ax.vlines(x=list(values_rolling[values_rolling.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values_rolling[values_rolling.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %%
# plot dataframe; the index is a datetime index
#ax = values_rolling[['value', 'upper', 'lower']].plot(figsize=(9, 6))
ax = values_rolling[['value', 'upper', 'lower']].plot(figsize=(12, 6))
ymin, ymax = values_rolling.value.min(), values_rolling.value.max()

ax.vlines(x=list(values_rolling[values_rolling.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values_rolling[values_rolling.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %%
ax = values_rolling.profit_raw.cumsum().plot(figsize=(9, 6))
ymin, ymax = values_rolling.profit_raw.cumsum().min(), values_rolling.profit_raw.cumsum().max()

ax.vlines(x=list(values_rolling[values_rolling.position_changed == +1].index), ymin=ymin, ymax=ymax, color='b', linestyles='dashed', label='enter')
ax.vlines(x=list(values_rolling[values_rolling.position_changed == -1].index), ymin=ymin, ymax=ymax, color='r', linestyles='solid', label='leave')

plt.show()

# %%
(values_rolling.profit_raw / values_rolling.position_size).cumsum().plot()
# Out:
# <Axes: xlabel='time'>

# %%
(values_rolling.position_size).plot()
# Out:
# <Axes: xlabel='time'>
